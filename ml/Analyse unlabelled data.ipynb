# %%
import pandas as pd
import numpy as np
LABEL_COLUMN = "Future8WeekReturn"

# %%
df = pd.read_pickle('./data/ml-2018-03-data.pkl.gz', compression='gzip')

# %%
df.drop(['Future1WeekDividend', 'Future1WeekPrice', 'Future1WeekReturn', 'Future1WeekRiskAdjustedReturn', 
         'Future2WeekDividend', 'Future2WeekPrice', 'Future2WeekReturn','Future2WeekRiskAdjustedReturn', 
         'Future4WeekDividend', 'Future4WeekPrice', 'Future4WeekReturn', 'Future4WeekRiskAdjustedReturn', 
         'Future8WeekDividend', 'Future8WeekPrice', 'Future8WeekReturn', 'Future8WeekRiskAdjustedReturn', 
         'Future12WeekDividend', 'Future12WeekPrice', 'Future12WeekReturn', 'Future12WeekRiskAdjustedReturn', 
         'Future26WeekDividend', 'Future26WeekPrice', 'Future26WeekReturn', 'Future26WeekRiskAdjustedReturn', 
         'Future52WeekDividend', 'Future52WeekPrice', 'Future52WeekReturn', 'Future52WeekRiskAdjustedReturn', 
         '1WeekVolatility', '2WeekVolatility', '4WeekVolatility', '8WeekVolatility', '12WeekVolatility', 
         '26WeekVolatility', '52WeekVolatility', '4WeekBollingerBandLower', '4WeekBollingerBandUpper', 
         '4WeekBollingerPrediction', '4WeekBollingerType', '12WeekBollingerBandLower', '12WeekBollingerBandUpper',
         '12WeekBollingerPrediction', '12WeekBollingerType'], axis=1, inplace=True)

# %%
df.columns.values
# Out:
# array(['symbol', 'quoteDate', 'lastTradePriceOnly', 'adjustedPrice',
#        'volume', 'daysHigh', 'daysLow', 'previousClose', 'change',
#        'changeInPercent', '52WeekHigh', '52WeekLow',
#        'changeFrom52WeekHigh', 'changeFrom52WeekLow',
#        'percebtChangeFrom52WeekHigh', 'percentChangeFrom52WeekLow',
#        'Price200DayAverage', 'Price52WeekPercChange',
#        'allordpreviousclose', 'allordchange', 'allorddayshigh',
#        'allorddayslow', 'allordpercebtChangeFrom52WeekHigh',
#        'allordpercentChangeFrom52WeekLow', 'asxpreviousclose',
#        'asxchange', 'asxdayshigh', 'asxdayslow',
#        'asxpercebtChangeFrom52WeekHigh', 'asxpercentChangeFrom52WeekLow',
#        'exDividendDate', 'exDividendPayout', '640106_A3597525W',
#        'AINTCOV', 'AverageVolume', 'Beta', 'BookValuePerShareYear',
#        'CashPerShareYear', 'DPSRecentYear', 'EBITDMargin', 'EPS',
#        'EPSGrowthRate10Years', 'EPSGrowthRate5Years', 'FIRMMCRT',
#        'FXRUSD', 'Float', 'GRCPAIAD', 'GRCPAISAD', 'GRCPBCAD',
#        'GRCPBCSAD', 'GRCPBMAD', 'GRCPNRAD', 'GRCPRCAD', 'H01_GGDPCVGDP',
#        'H01_GGDPCVGDPFY', 'H05_GLFSEPTPOP', 'IAD',
#        'LTDebtToEquityQuarter', 'LTDebtToEquityYear', 'MarketCap',
#        'NetIncomeGrowthRate5Years', 'NetProfitMarginPercent',
#        'OperatingMargin', 'PE', 'PriceToBook', 'QuoteLast',
#        'ReturnOnAssets5Years', 'ReturnOnAssetsTTM', 'ReturnOnAssetsYear',
#        'ReturnOnEquity5Years', 'ReturnOnEquityTTM', 'ReturnOnEquityYear',
#        'RevenueGrowthRate10Years', 'RevenueGrowthRate5Years',
#        'TotalDebtToAssetsQuarter', 'TotalDebtToAssetsYear',
#        'TotalDebtToEquityQuarter', 'TotalDebtToEquityYear', 'bookValue',
#        'earningsPerShare', 'ebitda', 'epsEstimateCurrentYear',
#        'marketCapitalization', 'peRatio', 'pegRatio', 'pricePerBook',
#        'pricePerEpsEstimateCurrentYear', 'pricePerEpsEstimateNextYear',
#        'pricePerSales'], dtype=object)

# %%
df[df['4WeekBollingerType'] != 'Within'][['symbol', 'quoteDate', 'adjustedPrice', '4WeekBollingerBandLower', '4WeekBollingerBandUpper',
       '4WeekBollingerPrediction', '4WeekBollingerType']]
# Out:
#         symbol  quoteDate  adjustedPrice  4WeekBollingerBandLower  \
# 3          LNY 2007-07-05       19.91998                14.791051
# 4          LNY 2007-07-06       20.87998                14.479592
# 5          LNY 2007-07-09       23.99998                13.562195
# 6          LNY 2007-07-10       22.79998                13.217986
# 32         LNY 2007-08-15       13.67999                14.335204
# 33         LNY 2007-08-16       12.71999                13.749653
# 34         LNY 2007-08-17       12.71999                13.058781
# 55         LNY 2007-09-17       11.99999                12.633728
# 61         LNY 2007-09-25       10.07999                11.023699
# 62         LNY 2007-09-26       10.55999                10.582308
# 73         LNY 2007-10-11       14.39999                 9.197997
# 114        LNY 2007-12-12        9.83999                 9.983637
# 115        LNY 2007-12-13        9.83999                 9.876099
# 119        LNY 2007-12-20        9.59999                 9.614050
# 135        LNY 2008-01-21        7.91999                 8.669680
# 136        LNY 2008-01-22        7.67999                 8.255808
# 155        LNY 2008-02-22        6.23999                 6.277241
# 176        LNY 2008-03-27        6.95999                 5.669553
# 181        LNY 2008-04-03        4.32000                 5.015313
# 204        LNY 2008-05-07        5.99999                 4.183878
# 205        LNY 2008-05-08        8.15999                 3.448024
# 206        LNY 2008-05-09        7.19999                 3.281937
# 223        LNY 2008-06-03        7.91999                 5.953586
# 224        LNY 2008-06-04        9.59999                 5.643996
# 225        LNY 2008-06-05       10.31999                 5.217796
# 226        LNY 2008-06-06       10.07999                 4.992882
# 246        LNY 2008-07-09        6.72000                 7.266320
# 247        LNY 2008-07-10        5.04000                 6.385000
# 248        LNY 2008-07-11        5.52000                 5.868023
# 265        LNY 2008-08-05        4.80000                 4.809851
# ...        ...        ...            ...                      ...
# 3294071    MOX 2016-10-04        0.01300                 0.011505
# 3294073    MOX 2016-10-06        0.01400                 0.011505
# 3294075    MOX 2016-10-10        0.01500                 0.010720
# 3294100    MOX 2016-11-25        0.01100                 0.011271
# 3294101    MOX 2016-11-28        0.01100                 0.011073
# 3294112    MOX 2016-12-14        0.01200                 0.010234
# 3294114    MOX 2016-12-16        0.01300                 0.010112
# 3294115    MOX 2016-12-19        0.01100                 0.010017
# 3294139    MOX 2017-02-10            NaN                      NaN
# 3294144    MOX 2017-02-17            NaN                      NaN
# 3294148    MOX 2017-02-24            NaN                      NaN
# 3294149    MOX 2017-02-28        0.00900                 0.009383
# 3294150    MOX 2017-03-01        0.00900                 0.009202
# 3294151    MOX 2017-03-03            NaN                      NaN
# 3294160    MOX 2017-03-22        0.01100                 0.008075
# 3294171    MOX 2017-04-12        0.01300                 0.008584
# 3294185    MOX 2017-05-12        0.00800                 0.008122
# 3294192    MOX 2017-05-26        0.00800                 0.008005
# 3294196    MOX 2017-06-06        0.00600                 0.006888
# 3294197    MOX 2017-06-07        0.00600                 0.006424
# 3294236    MOX 2017-09-06        0.00700                 0.004193
# 3294259    MOX 2017-10-16        0.00700                 0.004938
# 3294272    MOX 2017-11-13        0.00900                 0.005539
# 3294289    MOX 2017-12-15        0.00700                 0.007113
# 3294297    MOX 2018-01-04        0.00600                 0.006061
# 3294305    MOX 2018-01-18        0.00800                 0.005419
# 3294321    MOX 2018-02-21        0.00500                 0.005246
# 3294336    MOX 2018-03-25        0.00500                      NaN
# 3294337    MOX 2018-03-27        0.00600                      NaN
# 3294338    MOX 2018-03-28        0.00600                      NaN
#
#          4WeekBollingerBandUpper 4WeekBollingerPrediction 4WeekBollingerType
# 3                      19.672910                   Steady              Above
# 4                      20.224369                   Steady              Above
# 5                      21.693766                   Steady              Above
# 6                      22.517975                   Steady              Above
# 32                     20.968757                   Steady              Below
# 33                     20.666309                   Steady              Below
# 34                     20.685182                   Steady              Below
# 55                     15.182252                   Steady              Below
# 61                     15.592281                   Steady              Below
# 62                     15.721672                   Steady              Below
# 73                     14.177983                   Steady              Above
# 114                    11.208343                   Steady              Below
# 115                    11.195881                   Steady              Below
# 119                    11.289930                   Steady              Below
# 135                    10.410300                   Steady              Below
# 136                    10.632172                   Steady              Below
# 155                     8.578739                   Steady              Below
# 176                     6.906427                   Steady              Above
# 181                     7.344668                   Steady              Below
# 204                     5.584120                   Steady              Above
# 205                     6.631973                   Steady              Above
# 206                     6.966060                   Steady              Above
# 223                     7.846394                   Steady              Above
# 224                     8.515984                   Steady              Above
# 225                     9.158184                   Steady              Above
# 226                     9.671098                   Steady              Above
# 246                     9.989660                   Steady              Below
# 247                    10.534981                   Steady              Below
# 248                    10.691958                   Steady              Below
# 265                     7.430132                   Steady              Below
# ...                          ...                      ...                ...
# 3294071                 0.013995                   Steady              Above
# 3294073                 0.013995                   Steady              Above
# 3294075                 0.015280                   Steady              Above
# 3294100                 0.013629                   Steady              Below
# 3294101                 0.013727                   Steady              Below
# 3294112                 0.012566                   Steady              Above
# 3294114                 0.012788                   Steady              Above
# 3294115                 0.012983                   Steady              Above
# 3294139                      NaN                      NaN                NaN
# 3294144                      NaN                      NaN                NaN
# 3294148                      NaN                      NaN                NaN
# 3294149                 0.010617                   Steady              Below
# 3294150                 0.010702                   Steady              Below
# 3294151                      NaN                      NaN                NaN
# 3294160                 0.010687                   Steady              Above
# 3294171                 0.012178                   Steady              Above
# 3294185                 0.011767                   Steady              Below
# 3294192                 0.010295                   Steady              Below
# 3294196                 0.010112                   Steady              Below
# 3294197                 0.010276                   Steady              Below
# 3294236                 0.006730                   Steady              Above
# 3294259                 0.006795                   Steady              Above
# 3294272                 0.008692                   Steady              Above
# 3294289                 0.009173                   Steady              Below
# 3294297                 0.008272                   Steady              Below
# 3294305                 0.007914                   Steady              Above
# 3294321                 0.007754                   Steady              Below
# 3294336                      NaN                      NaN                NaN
# 3294337                      NaN                      NaN                NaN
# 3294338                      NaN                      NaN                NaN
#
# [428435 rows x 7 columns]

# %%
df['quoteDate'] = pd.to_datetime(df['quoteDate'])
df['exDividendDate'] = pd.to_datetime(df['exDividendDate'], errors='coerce')

# %%
df[df['quoteDate'].isnull()]

# %%
df['quoteDateRef'] = df['quoteDate']
df[df['quoteDateRef'].isnull()]

# %%
cols = ['symbol', 'quoteDate', 'quoteDateRef', 'adjustedPrice',
        #'1WeekVolatility', '2WeekVolatility', '4WeekVolatility', '8WeekVolatility',
        #'12WeekVolatility', '26WeekVolatility', '52WeekVolatility',
        'exDividendDate', 'exDividendPayout', 
        #'Future1WeekDividend', 'Future1WeekPrice', 'Future1WeekReturn', 'Future1WeekRiskAdjustedReturn',
        #'Future2WeekDividend', 'Future2WeekPrice', 'Future2WeekReturn', 'Future2WeekRiskAdjustedReturn', 
        #'Future4WeekDividend', 'Future4WeekPrice', 'Future4WeekReturn', 'Future4WeekRiskAdjustedReturn', 
        'Future8WeekDividend', 'Future8WeekPrice', 'Future8WeekReturn', 'Future8WeekRiskAdjustedReturn', 
        #'Future12WeekDividend', 'Future12WeekPrice', 'Future12WeekReturn', 'Future12WeekRiskAdjustedReturn', 
        #'Future26WeekDividend', 'Future26WeekPrice', 'Future26WeekReturn', 'Future26WeekRiskAdjustedReturn', 
        #'Future52WeekDividend', 'Future52WeekPrice', 'Future52WeekReturn','Future52WeekRiskAdjustedReturn'
       ]

#df[df['symbol'] == 'LNY']['quoteDate'].isnull()
#df[df['symbol'] == 'LNY']['quoteDateRef'].isnull()
indexed_df = df[df['symbol'] == 'JBH']
indexed_df.sort_values(by=['quoteDate'], inplace=True)
indexed_df = indexed_df.set_index('quoteDateRef')
indexed_df
#ser = pd.Series(df[df['symbol'] == 'LNY']['quoteDate'], df[df['symbol'] == 'LNY']['quoteDate'])
#ser[ser.isnull()]
#ser.sort_values(inplace=True)
#ser[ser.isnull()]

# %%
ref_vals_df = indexed_df[['quoteDate', 'adjustedPrice']].asof(indexed_df.index - pd.DateOffset(weeks=8))
ref_vals_df.rename(columns={'quoteDate': '8WeekRefDate', 'adjustedPrice': '8WeekPrice'}, inplace=True)
ref_vals_df.index = ref_vals_df.index + pd.DateOffset(weeks=8)
ref_vals_df

# %%
pd.concat([indexed_df, ref_vals_df], axis=1)
# indexed_df['futureReferenceDate'] = ref_vals_df.index
# indexed_df['futureClosestDate'] = ref_vals_df['quoteDate']
# indexed_df['futurePrice'] = ref_vals_df['adjustedPrice']
# indexed_df
#indexed_df[(indexed_df.index > '2017-10-01') & (indexed_df[LABEL_COLUMN].isna())].head(120)

# %%
period_min, period_max, period_mean, period_median, period_std, period_bollinger_upper, period_bollinger_lower = calculate_week_stats(1, indexed_df['adjustedPrice'])
print(period_min.head(10))
print(period_max.head(10))
print(period_mean.head(10))
print(period_median.head(10))
print(period_std.head(10))
print(period_bollinger_upper.head(10))
print(period_bollinger_lower.head(10))

# %%
# Test methods for calculating stats
date_col = 'quoteDate'
price_col = 'adjustedPrice'
num_weeks = 4
date_ref_col = date_col + '_ref'
# Sort new df by date and add the reference date column as the index
indexed_df = df[df['symbol'] == 'LNY']
indexed_df[date_ref_col] = indexed_df[date_col]
indexed_df.sort_values(by=[date_col], inplace=True)
indexed_df = indexed_df.set_index(date_ref_col)

indexed_df = calculate_week_stats(num_weeks, indexed_df, price_col)
# indexed_df
# indexed_df[indexed_df['4_week_bollinger_prediction']!= 'Steady']
# indexed_df[indexed_df['4_week_bollinger_type']!= 'Within']
calculate_week_price_return(num_weeks, indexed_df, price_col)

# %%
def calculate_week_stats(num_weeks, df, price_col):
    rolling_expression = str(num_weeks * 7) + 'D'
    rolling_window = df[price_col].rolling(rolling_expression)
    prefix = str(num_weeks)
    df[prefix + '_week_min'] = rolling_window.min()
    df[prefix + '_week_max'] = rolling_window.max()
    df[prefix + '_week_mean'] = rolling_window.mean()
    df[prefix + '_week_median'] = rolling_window.median()
    df[prefix + '_week_std'] = rolling_window.std()
    df[prefix + '_week_bollinger_upper'] = rolling_window.mean() + (2 *rolling_window.std())
    df[prefix + '_week_bollinger_lower'] = rolling_window.mean() - (2 *rolling_window.std())
        
    # Set bollinger predictions: above -> within = falling, below -> within = rising
    bollinger_types = []
    bollinger_predictions = []
    bollinger_previous_value = ''
    
    # Create bollinger values dataframe
    bollinger_df = df[[price_col, prefix + '_week_bollinger_upper', prefix + '_week_bollinger_lower']]
    
    # Loop through, calulcate bollinger value predictors and compare to previous result
    for row in bollinger_df.itertuples():
        current_price = row[1]
        bollinger_upper = row[2]
        bollinger_lower = row[3]
        
        if current_price > bollinger_upper:
            bollinger_value =  'Above'
        elif current_price < bollinger_lower:
            bollinger_value = 'Below'
        else: 
            bollinger_value = 'Within'
        
        # Append bollinger value to type to list
        bollinger_types.append(bollinger_value)
        
        if (bollinger_value == 'Within') & (bollinger_previous_value == 'Above'):
            bollinger_predictions.append('Falling')
        elif (bollinger_value == 'Within') & (bollinger_previous_value == 'Below'):
            bollinger_predictions.append('Rising')
        else:
            bollinger_predictions.append('Steady')
        
        # Reset value for next iteration
        bollinger_previous_value = bollinger_value

    # Add results to dataframe
    df[prefix + '_week_bollinger_type'] = bollinger_types
    df[prefix + '_week_bollinger_prediction'] = bollinger_predictions
    
    return df

# %%
def calculate_week_price_return(num_weeks, df, price_col):
    df_col = df[price_col]
    index = df_col.index
    comparison_date = index - pd.DateOffset(weeks=num_weeks)
    prefix = str(num_weeks)

    # Create offset for number of weeks - this resets the index value
    ref_vals_df = pd.DataFrame()
    ref_vals_df[prefix + '_week_comparison_' + price_col] = df_col.asof(comparison_date)
    ref_vals_df[prefix + '_week_comparison_date'] = comparison_date
    
    # Reset the index value back to original
    ref_vals_df.index = index
    
    # concatenate the offset values with the original values
    combined_vals = pd.concat([df, ref_vals_df], axis=1)
    combined_vals[prefix + '_week_price_change'] = combined_vals[price_col] - combined_vals[prefix + '_week_comparison_' + price_col]
    combined_vals[prefix + '_week_price_return'] = combined_vals[prefix + '_week_price_change'] / combined_vals[price_col] * 100
    
    return combined_vals

# %%
def calculate_period_dividends(df, dividend_date_col, dividend_payout_col, start_date, end_date):
    # Limit results to period
    ref_vals_df = df[(df.index >= start_date) & (df.index < end_date)]
    # Limit cols to dividens cols
    ref_vals_df = ref_vals_df[[dividend_date_col, dividend_payout_col]]
    # Drop duplicates
    unique_dividends = ref_vals_df.drop_duplicates()
    
    # Sum dividends which have an ex-dividend date within the time period
    total_dividends = 0

    for row in unique_dividends.itertuples():
        if (str(row[1]) >= start_date) & (str(row[1]) <= end_date):
            total_dividends = total_dividends + row[2]

    return total_dividends

# %%
num_weeks = 4
date_col = 'quoteDate'
price_col = 'adjustedPrice'
dividend_date_col = 'exDividendDate'
dividend_payout_col = 'exDividendPayout'

calculate_dividend_returns(num_weeks, indexed_df, date_col, price_col, dividend_date_col, dividend_payout_col)

# %%
def calculate_dividend_returns(num_weeks, df, date_col, price_col, dividend_date_col, dividend_payout_col):
    dividend_column = []
    prefix = str(num_weeks)
    
    dividend_dates = pd.DataFrame()
    dividend_dates['dividend_period_start'] = df.index - pd.DateOffset(weeks=num_weeks)
    dividend_dates['dividend_period_end'] = df.index
    
    for row in dividend_dates.itertuples(index=False):
#         print(row)
        dividend_period_start = str(row[0])
        dividend_period_end = str(row[1])
#         print(dividend_period_start, dividend_period_end)
        dividends = calculate_period_dividends(df, dividend_date_col, dividend_payout_col, dividend_period_start, 
                                               dividend_period_end)
        dividend_column.append(dividends)
    
    transformed_df = df
    transformed_df[prefix + '_week_dividend_value'] = dividend_column
    transformed_df[prefix + '_week_dividend_return'] = transformed_df[prefix + '_week_dividend_value'] / transformed_df[price_col] * 100

    return transformed_df

# %%
def add_stats_and_returns(num_weeks, df, date_col, price_col, dividend_date_col, dividend_payout_col):
    # Create a new reference field for the date column
    date_ref_col = date_col + '_ref'
    prefix = str(num_weeks)
    # Sort new df by date and add the reference date column as the index
    indexed_df = df
    indexed_df[date_ref_col] = indexed_df[date_col]
    indexed_df.sort_values(by=[date_col], inplace=True)
    indexed_df = indexed_df.set_index(date_ref_col)
    
    # Add stats cols
    indexed_df = calculate_week_stats(num_weeks, indexed_df, price_col)
        
    # Calculate price returns
    indexed_df = calculate_week_price_return(num_weeks, indexed_df, price_col) 
    
    # Calculate dividend returns
    indexed_df = calculate_dividend_returns(num_weeks, indexed_df, date_col, price_col, dividend_date_col, dividend_payout_col)
    
    # Add in total period returns
    indexed_df[prefix + '_week_total_return'] = indexed_df[prefix + '_week_dividend_return'] + indexed_df[prefix + '_week_price_return']
    
    return indexed_df

# %%
# Set up config values for calculation
return_weeks = [1, 2, 4, 8, 12, 26, 52]
date_col = 'quoteDate'
price_col = 'adjustedPrice'
dividend_date = 'exDividendDate'
dividend_payout = 'exDividendPayout'
symbol = 'JBH'
num_weeks = 8

# Reduce the data to the supplied symbol
transformed_df = df[df['symbol'] == symbol]

for week in return_weeks:
    transformed_df = add_stats_and_returns(week, transformed_df, date_col, price_col, 
                                           dividend_date_col, dividend_payout_col)
transformed_df

# %%
def transform_symbol_returns(df, symbol):
    # Set up config values for calculation
    return_weeks = [1, 2, 4, 8, 12, 26, 52]
    date_col = 'quoteDate'
    price_col = 'adjustedPrice'
    dividend_date = 'exDividendDate'
    dividend_payout = 'exDividendPayout'

    # Reduce the data to the supplied symbol
    transformed_df = df[df['symbol'] == symbol]
    
    for week in return_weeks:
        transformed_df = add_stats_and_returns(week, transformed_df, date_col, price_col, 
                                               dividend_date_col, dividend_payout_col)
        
    return transformed_df

# %%
# Execute all transform for a symbol
transform_symbol_returns(df, 'JBH')
# Out:
# /Users/neilkloot/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/neilkloot/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               symbol  quoteDate  lastTradePriceOnly  adjustedPrice   volume  \
# quoteDate_ref
# 2007-07-02       JBH 2007-07-02            10.96580       5.708538   449000
# 2007-07-03       JBH 2007-07-03            11.06460       5.759972   511100
# 2007-07-04       JBH 2007-07-04            11.22270       5.842275   628300
# 2007-07-05       JBH 2007-07-05            11.32150       5.893706   694600
# 2007-07-06       JBH 2007-07-06            11.35110       5.909116   676500
# 2007-07-09       JBH 2007-07-09            11.25230       5.857683   526500
# 2007-07-10       JBH 2007-07-10            11.12390       5.790843   396100
# 2007-07-11       JBH 2007-07-11            11.26220       5.862837   682400
# 2007-07-12       JBH 2007-07-12            11.65740       6.068568   680700
# 2007-07-13       JBH 2007-07-13            11.71670       6.099439   396700
# 2007-07-16       JBH 2007-07-16            11.72650       6.104540   452400
# 2007-07-17       JBH 2007-07-17            12.09210       6.294864   718700
# 2007-07-18       JBH 2007-07-18            12.24020       6.371962   891600
# 2007-07-19       JBH 2007-07-19            12.06240       6.279403   635500
# 2007-07-20       JBH 2007-07-20            11.85500       6.171433   415800
# 2007-07-23       JBH 2007-07-23            11.58820       6.032543   480800
# 2007-07-24       JBH 2007-07-24            11.44990       5.960550   656000
# 2007-07-25       JBH 2007-07-25            11.21280       5.837121   643300
# 2007-07-26       JBH 2007-07-26            11.08440       5.770279  1102000
# 2007-07-27       JBH 2007-07-27            10.79790       5.621134   986400
# 2007-07-30       JBH 2007-07-30            11.14370       5.801148   462200
# 2007-07-31       JBH 2007-07-31            11.65740       6.068568   519200
# 2007-08-01       JBH 2007-08-01            11.06460       5.759972   445300
# 2007-08-02       JBH 2007-08-02            10.37310       5.399992   888200
# 2007-08-03       JBH 2007-08-03            10.57070       5.502859   678300
# 2007-08-06       JBH 2007-08-06            10.37310       5.399992   482700
# 2007-08-07       JBH 2007-08-07            10.49160       5.461682   495400
# 2007-08-08       JBH 2007-08-08            10.45210       5.441117   303400
# 2007-08-09       JBH 2007-08-09            10.07670       5.245693   626300
# 2007-08-10       JBH 2007-08-10             9.63216       5.014276  1253300
# ...              ...        ...                 ...            ...      ...
# 2018-02-16       JBH 2018-02-16            26.78000      26.780000   480162
# 2018-03-26                   1.885700                 7.320264
# 2018-03-27                   1.885700                 7.277885
# 2018-03-28                   1.885700                 7.308915
# 2018-03-29                   1.885700                 7.306083
#
#                52_week_total_return
# quoteDate_ref
# 2007-07-02                      NaN
# 2007-07-03                      NaN
# 2007-07-04                      NaN
# 2007-07-05                      NaN
# 2007-07-06                      NaN
# 2007-07-09                      NaN
# 2007-07-10                      NaN
# 2007-07-11                      NaN
# 2007-07-12                      NaN
# 2007-07-13                      NaN
# 2007-07-16                      NaN
# 2007-07-17                      NaN
# 2007-07-18                      NaN
# 2007-07-19                      NaN
# 2007-07-20                      NaN
# 2007-07-23                      NaN
# 2007-07-24                      NaN
# 2007-07-25                      NaN
# 2007-07-26                      NaN
# 2007-07-27                      NaN
# 2007-07-30                      NaN
# 2007-07-31                      NaN
# 2007-08-01                      NaN
# 2007-08-02                      NaN
# 2007-08-03                      NaN
# 2007-08-06                      NaN
# 2007-08-07                      NaN
# 2007-08-08                      NaN
# 2007-08-09                      NaN
# 2007-08-10                      NaN
# ...                             ...
# 2018-02-16                17.173936
# 2018-02-19                16.249658
# 2018-02-20                17.640613
# 2018-02-21                13.327036
# 2018-02-22                11.429558
# 2018-02-23                15.993451
# 2018-02-26                15.209427
# 2018-02-27                16.033397
# 2018-02-28                12.494601
# 2018-03-01                15.169920
# 2018-03-02                14.745443
# 2018-03-05                13.332015
# 2018-03-06                16.320451
# 2018-03-07                15.789590
# 2018-03-08                16.901396
# 2018-03-09                 9.686834
# 2018-03-12                17.177930
# 2018-03-13                17.373923
# 2018-03-14                17.917714
# 2018-03-15                18.385841
# 2018-03-16                12.960687
# 2018-03-19                22.277035
# 2018-03-20                23.544221
# 2018-03-21                21.708091
# 2018-03-22                21.383627
# 2018-03-23                12.917937
# 2018-03-26                20.774755
# 2018-03-27                18.610760
# 2018-03-28                18.552391
# 2018-03-29                18.223286
#
# [2719 rows x 201 columns]

# %%
all_symbols = df['symbol'].values
symbols = np.unique(all_symbols)

#Create empty data frame
output_df = pd.DataFrame()

for symbol in symbols:
    symbol_df = transform_symbol_returns(df, symbol)
    
    # Add data frame into all results
    output_df = pd.concat([output_df, symbol_df])

output_df

# %%
# Execute symbol returns and stats 
symbol = 'JBH'
date_col = 'quoteDate'
price_col = 'adjustedPrice'
dividend_date = 'exDividendDate'
dividend_payout = 'exDividendPayout'
updated_df = add_stats_and_returns(1, df, symbol, date_col, price_col, dividend_date, dividend_payout)

# %%
rolling_window = indexed_df['adjustedPrice'].rolling('7D')

# %%
rolling_window.count()

# %%
rolling_window.max()

# %%
rolling_window.min()

# %%
rolling_window.mean()

# %%
rolling_window.median()

# %%
rolling_window.std()

# %%
rolling_window.mean() + (2 * rolling_window.std())

# %%
rolling_window.mean() - (2 * rolling_window.std())

# %%
    df_col = df[price_col]
    index = df.index
    comparison_date = index - pd.DateOffset(weeks=num_weeks)

    # Create offset for number of weeks - this resets the index value
    ref_vals_df = df[price_col]
    ref_vals_df.head(5)
    ref_vals_df['comparison_' + price_col] = df[price_col].asof(comparison_date)
    ref_vals_df['comparison_date'] = comparison_date
    
    ref_vals_df.head(5)

    # Reset the index value back to original
#     ref_vals_df.index = index
#     ref_vals_df['quoteDate'] = index
    ref_vals_df.head(5)

    # Create offset for number of weeks - this resets the index value
    ref_vals_df = df['comparison_' + price_col].asof(index - pd.DateOffset(weeks=num_weeks))
    ref_vals_df.head(5)
    
    # Reset the index value back to original
    ref_vals_df.index = ref_vals_df.index + pd.DateOffset(weeks=num_weeks)
    ref_vals_df.head(5)
    
    # concatenate the offset values with the original values
    combined_vals = pd.concat([df, ref_vals_df], axis=1)

# %%
price_col = 'adjustedPrice'
df_col = indexed_df[price_col]
index = indexed_df.index
comparison_date = index - pd.DateOffset(weeks=1)

# Create offset for number of weeks - this resets the index value
ref_vals_df = pd.DataFrame()
ref_vals_df['comparisonPrice'] = df_col.asof(comparison_date)
ref_vals_df['comparisonDate'] = comparison_date

# Reset the index value back to original
ref_vals_df.index = index
ref_vals_df['quoteDate'] = index
ref_vals_df
# Out:
#                comparisonPrice comparisonDate  quoteDate
# quoteDate_ref
# 2007-07-02                 NaN     2007-06-25 2007-07-02
# 2007-07-03                 NaN     2007-06-26 2007-07-03
# 2007-07-04                 NaN     2007-06-27 2007-07-04
# 2007-07-05                 NaN     2007-06-28 2007-07-05
# 2007-07-06                 NaN     2007-06-29 2007-07-06
# 2007-07-09            16.79998     2007-07-02 2007-07-09
# 2007-07-10            17.27998     2007-07-03 2007-07-10
# 2007-07-11            18.23998     2007-07-04 2007-07-11
# 2007-07-12            19.91998     2007-07-05 2007-07-12
# 2007-07-13            20.87998     2007-07-06 2007-07-13
# 2007-07-16            23.99998     2007-07-09 2007-07-16
# 2007-07-17            22.79998     2007-07-10 2007-07-17
# 2007-07-18            23.03998     2007-07-11 2007-07-18
# 2007-07-19            22.31998     2007-07-12 2007-07-19
# 2007-07-20            22.31998     2007-07-13 2007-07-20
# 2007-07-23            22.55998     2007-07-16 2007-07-23
# 2007-07-24            22.79998     2007-07-17 2007-07-24
# 2007-07-25            22.79998     2007-07-18 2007-07-25
# 2007-07-26            21.59998     2007-07-19 2007-07-26
# 2007-07-27            19.43998     2007-07-20 2007-07-27
# 2007-07-30            19.43998     2007-07-23 2007-07-30
# 2007-07-31            18.23998     2007-07-24 2007-07-31
# 2007-08-01            17.99998     2007-07-25 2007-08-01
# 2007-08-02            19.91998     2007-07-26 2007-08-02
# 2007-08-03            17.99998     2007-07-27 2007-08-03
# 2007-08-06            17.99998     2007-07-30 2007-08-06
# 2007-08-07            17.99998     2007-07-31 2007-08-07
# 2007-08-08            17.75998     2007-08-01 2007-08-08
# 2007-08-09            17.75998     2007-08-02 2007-08-09
# 2007-08-10            17.99998     2007-08-03 2007-08-10
# ...                        ...            ...        ...
# 2018-01-18             0.00400     2018-01-11 2018-01-18
# 2018-01-19             0.00400     2018-01-12 2018-01-19
# 2018-01-22             0.00400     2018-01-15 2018-01-22
# 2018-01-23             0.00400     2018-01-16 2018-01-23
# 2018-01-24             0.00400     2018-01-17 2018-01-24
# 2018-01-25             0.00400     2018-01-18 2018-01-25
# 2018-01-29             0.00300     2018-01-22 2018-01-29
# 2018-01-31             0.00400     2018-01-24 2018-01-31
# 2018-02-01             0.00400     2018-01-25 2018-02-01
# 2018-02-02             0.00400     2018-01-26 2018-02-02
# 2018-02-05             0.00400     2018-01-29 2018-02-05
# 2018-02-06             0.00400     2018-01-30 2018-02-06
# 2018-02-08             0.00300     2018-02-01 2018-02-08
# 2018-02-09             0.00400     2018-02-02 2018-02-09
# 2018-02-12             0.00300     2018-02-05 2018-02-12
# 2018-02-15             0.00400     2018-02-08 2018-02-15
# 2018-02-20             0.00300     2018-02-13 2018-02-20
# 2018-02-21             0.00300     2018-02-14 2018-02-21
# 2018-03-01             0.00300     2018-02-22 2018-03-01
# 2018-03-08             0.00300     2018-03-01 2018-03-08
# 2018-03-09             0.00300     2018-03-02 2018-03-09
# 2018-03-12             0.00300     2018-03-05 2018-03-12
# 2018-03-14             0.00300     2018-03-07 2018-03-14
# 2018-03-16             0.00300     2018-03-09 2018-03-16
# 2018-03-19             0.00300     2018-03-12 2018-03-19
# 2018-03-20             0.00300     2018-03-13 2018-03-20
# 2018-03-22             0.00300     2018-03-15 2018-03-22
# 2018-03-26             0.00300     2018-03-19 2018-03-26
# 2018-03-27             0.00300     2018-03-20 2018-03-27
# 2018-03-28             0.00300     2018-03-21 2018-03-28
#
# [1840 rows x 3 columns]

# %%
# concatenate the offset values with the original values
combined_vals = pd.concat([df_col, ref_vals_df, indexed_df[['exDividendDate', 'exDividendPayout']]], axis=1)
combined_vals['priceChange'] = combined_vals['adjustedPrice'] - combined_vals['comparisonPrice']
combined_vals['priceReturn'] = combined_vals['priceChange'] / combined_vals['adjustedPrice'] * 100
combined_vals

# %%
# Test period dividends
combined_vals['periodDividends'] = calculate_period_dividends(combined_vals[['exDividendDate', 'exDividendPayout']], 
                                                              combined_vals.index,
                                                              combined_vals['comparisonDate'],
                                                              combined_vals['quoteDate'])

combined_vals

# %%
df_col = combined_vals[['exDividendDate', 'exDividendPayout']]
index = combined_vals.index
dividend_column = []

for row in combined_vals.itertuples():
#     print(row)
#     print(row[3], '-', row[4])
    dividends = calculate_period_dividends(df_col, index, str(row[3]), str(row[4]))
#     print(dividends)
    dividend_column.append(dividends)
    
# print(dividend_column)
# np_dividends = np.array(dividend_column)
# print(np_dividends)
combined_vals['dividend_return'] = dividend_column
combined_vals

# %%
df_col = indexed_df[['exDividendDate', 'exDividendPayout']]
index = indexed_df.index

start_date = '2018-02-20'
end_date = '2018-02-27'
# Create offset for number of weeks - this resets the index value
ref_vals_df = df_col[(df_col.index >= start_date) & (df_col.index < end_date)]
unique_dividends = ref_vals_df.drop_duplicates()

total_dividends = 0

for row in unique_dividends.itertuples():
    print(row)
    print(str(row[1]))
    print(str(row[2]))
    print((str(row[1]) > start_date))
    print(str(row[1]) < end_date)
    if (str(row[1]) > start_date) &  (str(row[1]) < end_date):
        print('Adding dividend')
        total_dividends = total_dividends + row[2]

total_dividends
